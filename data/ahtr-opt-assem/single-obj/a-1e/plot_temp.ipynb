# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_centerline = pd.read_csv("./most_minimized_gen2_64/straight_centerline_results/fhr_assem_moltres_csv_flux_centerline_0003.csv")
df_diagonal = pd.read_csv("./most_minimized_gen2_64/fhr_assem_moltres_csv_flux_centerline_0003.csv")

# %%
fig, ax = plt.subplots(figsize=(15,7))
ax.scatter(df_centerline['y'], df_centerline['temp'], marker='*',label="vertical")
#ax.scatter(df_diagonal['y'], df_diagonal['temp'], marker='*', label="diagonal")
ax.set_ylabel("Temperature [K]", fontsize=24)
ax.set_xlabel("y [cm]", fontsize=24)
ax.grid()
ax.set_title("One-Third Assembly Centerline Temperature", fontsize=28)
#handles, labels = ax.get_legend_handles_labels()
#ax.legend(handles, labels, fontsize=18, bbox_to_anchor = [1.0, 1.0])
ax.tick_params(axis='both', which='major', labelsize=16)
#ax.set_ylim([900, 1200])
#ax.set_xticks([19.775, 16.525, 13.275, 10.025,  6.775,  3.525])
#ax.set_xlim([0, 23.4])
plt.savefig("a-1e-temp-distribution-centerline.png",bbox_inches='tight')

# %%
fig, ax = plt.subplots(figsize=(15,7))
#ax.scatter(df_centerline['y'], df_centerline['temp'], marker='*')
ax.scatter(df_diagonal['y'], df_diagonal['temp'], marker='*')
ax.set_ylabel("Temperature [K]", fontsize=20)
ax.set_xlabel("y [cm]", fontsize=20)
ax.grid()
ax.set_title("One-Third Assembly Centerline Temperature", fontsize=24)
#ax.set_ylim([900, 1200])
#ax.set_xticks([19.775, 16.525, 13.275, 10.025,  6.775,  3.525])
#ax.set_xlim([0, 23.4])
#plt.savefig("a-1e-temp-distribution-centerline.png",bbox_inches='tight')
# Out:
# Text(0.5, 1.0, 'One-Third Assembly Centerline Temperature')
